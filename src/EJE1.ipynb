# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_base = pd.read_csv(r'..\data\dataset_wTotal.csv')

# %%
df_base.shape
df_base.head(10)
# Out:
#      id  year_birth   education marital_status   income  kidhome  teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
# 5  7446        1967      Master       Together  62513.0        0         1
# 6   965        1971  Graduation       Divorced  55635.0        0         1
# 7  6177        1985         PhD        Married  33454.0        1         0
# 8  4855        1974         PhD       Together  30351.0        1         0
# 9  5899        1950         PhD       Together   5648.0        1         1
#
#   dt_customer  recency  mntwines  ...  acceptedcmp3  acceptedcmp4  \
# 0  2012-09-04       58       635  ...             0             0
# ...

# %%
df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2240 non-null   int64
#  1   year_birth           2240 non-null   int64
#  2   education            2240 non-null   object
#  3   marital_status       2240 non-null   object
#  4   income               2216 non-null   float64
#  5   kidhome              2240 non-null   int64
#  6   teenhome             2240 non-null   int64
#  7   dt_customer          2240 non-null   object
#  8   recency              2240 non-null   int64
#  9   mntwines             2240 non-null   int64
#  10  mntfruits            2240 non-null   int64
#  11  mntmeatproducts      2240 non-null   int64
#  12  mntfishproducts      2240 non-null   int64
#  13  mntsweetproducts     2240 non-null   int64
#  14  mntgoldprods         2240 non-null   int64
# ...

# %% [markdown]
# **Podemos observar que no hay ningun nulo en el csv, con lo cual no hay que eliminar nulos.**

# %%
df_base.describe(include=[np.number])
# Out:
#                  id   year_birth         income      kidhome     teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            recency     mntwines    mntfruits  mntmeatproducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
columns = df_base.columns
columns = [column.lower() for column in columns]
columns = [column.replace(' ', '_') for column in columns]
df_base.columns = columns

# %%
df_base.head(10)
# Out:
#      id  year_birth   education marital_status   income  kidhome  teenhome  \
# 0  5524        1957  Graduation         Single  58138.0        0         0
# 1  2174        1954  Graduation         Single  46344.0        1         1
# 2  4141        1965  Graduation       Together  71613.0        0         0
# 3  6182        1984  Graduation       Together  26646.0        1         0
# 4  5324        1981         PhD        Married  58293.0        1         0
# 5  7446        1967      Master       Together  62513.0        0         1
# 6   965        1971  Graduation       Divorced  55635.0        0         1
# 7  6177        1985         PhD        Married  33454.0        1         0
# 8  4855        1974         PhD       Together  30351.0        1         0
# 9  5899        1950         PhD       Together   5648.0        1         1
#
#   dt_customer  recency  mntwines  ...  acceptedcmp3  acceptedcmp4  \
# 0  2012-09-04       58       635  ...             0             0
# ...

# %% [markdown]
# **Aunque no se han encontrado valores nulos, vamos a borrar en aquellas columnas que queramos utilizar los nulos, solo en aquellas que sean interesantes.**

# %%
df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2240 non-null   int64
#  1   year_birth           2240 non-null   int64
#  2   education            2240 non-null   object
#  3   marital_status       2240 non-null   object
#  4   income               2216 non-null   float64
#  5   kidhome              2240 non-null   int64
#  6   teenhome             2240 non-null   int64
#  7   dt_customer          2240 non-null   object
#  8   recency              2240 non-null   int64
#  9   mntwines             2240 non-null   int64
#  10  mntfruits            2240 non-null   int64
#  11  mntmeatproducts      2240 non-null   int64
#  12  mntfishproducts      2240 non-null   int64
#  13  mntsweetproducts     2240 non-null   int64
#  14  mntgoldprods         2240 non-null   int64
# ...

# %% [markdown]
# ****Deteccion de outliers y pintado de los mismos sobre los valores de income****

# %%
# 2. Detección de valores atípicos en columnas numéricas
numerical_cols = ['income', 'mntwines', 'mntfruits', 'mntmeatproducts', 'mntfishproducts']

# Crear boxplots para todas las columnas numéricas
plt.figure(figsize=(20, 15))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(6, 4, i)
    sns.boxplot(y=df_base[col])
    plt.title(f'Boxplot de {col}')
    plt.tight_layout()

plt.show()

# %%
# Detección y eliminación de outliers para múltiples columnas
numerical_cols = ['income', 'mntwines', 'mntfruits', 'mntmeatproducts', 'mntfishproducts']

# Crear una copia del dataframe para limpiar
df_clean = df_base.copy()

# Función para eliminar outliers usando IQR
def remove_outliers(df, column):
    Q1 = df_base[column].quantile(0.25)
    Q3 = df_base[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df_base[column] >= lower_bound) & (df_base[column] <= upper_bound)]

# Aplicar la función a cada columna numérica
for col in numerical_cols:
    df_clean = remove_outliers(df_clean, col)

# Crear boxplots para las columnas limpias
plt.figure(figsize=(20, 15))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(6, 4, i)
    sns.boxplot(y=df_clean[col])
    plt.title(f'Boxplot sin outliers de {col}')
    plt.tight_layout()

plt.show

print(f"Datos originales: {df_base.shape[0]}")
print(f"Datos después de eliminar outliers: {df_clean.shape[0]}")
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_4416\2739489446.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   return df[(df_base[column] >= lower_bound) & (df_base[column] <= upper_bound)]
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_4416\2739489446.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   return df[(df_base[column] >= lower_bound) & (df_base[column] <= upper_bound)]
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_4416\2739489446.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   return df[(df_base[column] >= lower_bound) & (df_base[column] <= upper_bound)]
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_4416\2739489446.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   return df[(df_base[column] >= lower_bound) & (df_base[column] <= upper_bound)]
# Datos originales: 2240
# ...

# %% [markdown]
# **EJERCICIO 1**
# # ¿Existe una relación entre los ingresos anuales de los clientes y la cantidad de dinero que gastan en iFood? Visualiza la relación con un gráfico y describe tus conclusiones.

# %%
productos = ['mntwines', 'mntfruits', 'mntmeatproducts', 'mntfishproducts', 'mntsweetproducts', 'mntgoldprods']
df_base['total_spend'] = df_base[productos].sum(axis=1)

# %%
correlacion = df_base[['income', 'total_spend']].corr()
print("\nCorrelación entre Ingresos y Gasto Total:\n", correlacion)
# Out:
# Correlación entre Ingresos y Gasto Total:
#                 income  total_spend
# income       1.000000     0.667576
# total_spend  0.667576     1.000000

# %%
g = sns.scatterplot(x='income', y='mnt_total', data=df_clean)
sns.regplot(x='income', y='mnt_total', data=df_clean, scatter=False, ax=g)
plt.title('Relación entre Ingresos y Gasto Total en iFood')
plt.xlabel('Ingresos Anuales')
plt.ylabel('Gasto Total')


plt.xlim(0, 150000)  
plt.ylim(0, 2000)    

plt.show()

# %% [markdown]
# Sí existe una relación significativa entre los ingresos anuales de los clientes y la cantidad de dinero que gastan en iFood. Sin embargo, el comportamiento de consumo no es estrictamente proporcional a los ingresos, lo que sugiere que otros factores (como promociones, preferencias o situación familiar) podrían influir en el gasto
